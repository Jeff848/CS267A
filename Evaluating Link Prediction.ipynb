# %%
import pandas as pd
import random

# Read the triples from the file
df = pd.read_csv('drkg.tsv', sep='\t', header=None, names=['head', 'relation', 'tail'])

# %%
df.info
# Out:
# <bound method DataFrame.info of                 head                        relation         tail
# 0         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::2157
# 1         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::5264
# 2         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::2158
# 3         Gene::2157  bioarx::HumGenHumGen:Gene:Gene   Gene::3309
# 4         Gene::2157  bioarx::HumGenHumGen:Gene:Gene  Gene::28912
# ...              ...                             ...          ...
# 5874256  Gene::29099     STRING::REACTION::Gene:Gene   Gene::1643
# 5874257  Gene::51645     STRING::REACTION::Gene:Gene   Gene::3183
# 5874258    Gene::865    STRING::CATALYSIS::Gene:Gene    Gene::983
# 5874259   Gene::1066      STRING::BINDING::Gene:Gene   Gene::7365
# 5874260   Gene::6118      STRING::BINDING::Gene:Gene   Gene::1111
#
# [5874261 rows x 3 columns]>

# %%
from pykeen.triples import TriplesFactory

# %%
#Get previously used training triples
rules_training_triples = TriplesFactory.from_path_binary('TransE + rules/training_triples')
no_rules_training_triples = TriplesFactory.from_path_binary('TransE (no rules)/training_triples')\

# %%
#Filter out entities/relations that weren't in the training data ()
df_rules_sample = df.loc[df['head'].isin(rules_training_triples.entity_to_id)]
df_rules_sample = df_sample.loc[df['tail'].isin(rules_training_triples.entity_to_id)]
df_rules_sample = df_sample.loc[df['relation'].isin(rules_training_triples.relation_to_id)]

# %%
df_no_rules_sample = df.loc[df['head'].isin(no_rules_training_triples.entity_to_id)]
df_no_rules_sample = df_sample.loc[df['tail'].isin(no_rules_training_triples.entity_to_id)]
df_no_rules_sample = df_sample.loc[df['relation'].isin(no_rules_training_triples.relation_to_id)]

# %%
# Check if there are at least 10,000 records
if len(df_rules_sample) < 10000:
    print("The file has fewer than 10,000 records.")
else:
    # Randomly select 10,000 records
    df_rules_sample = df_rules_sample.sample(n=10000, random_state=random.randint(1, 100))

# %%
# Check if there are at least 10,000 records
if len(df_no_rules_sample) < 10000:
    print("The file has fewer than 10,000 records.")
else:
    # Randomly select 10,000 records
    df_no_rules_sample = df_no_rules_sample.sample(n=10000, random_state=random.randint(1, 100))

# %%
df_rules_sample.head(10)
# Out:
#                       head                                        relation  \
# 634752   Compound::DB00700  DRUGBANK::ddi-interactor-in::Compound:Compound
# 409437   Compound::DB00425  DRUGBANK::ddi-interactor-in::Compound:Compound
# 156610   Compound::DB00105  DRUGBANK::ddi-interactor-in::Compound:Compound
# 3518360  Compound::DB01059            Hetionet::CcSE::Compound:Side Effect
# 3155335         Gene::6608                       Hetionet::Gr>G::Gene:Gene
# 5138217         Gene::7039                      STRING::BINDING::Gene:Gene
# 1371227  Compound::DB09273  DRUGBANK::ddi-interactor-in::Compound:Compound
# 1257977  Compound::DB06738  DRUGBANK::ddi-interactor-in::Compound:Compound
# 1984127          Gene::528         Hetionet::GpBP::Gene:Biological Process
# 2459037         Gene::6310                        Hetionet::GiG::Gene:Gene
#
#                                    tail
# 634752                Compound::DB01366
# 409437                Compound::DB01175
# 156610                Compound::DB13203
# 3518360           Side Effect::C0011991
# 3155335                      Gene::1066
# 5138217                      Gene::9919
# 1371227               Compound::DB12338
# 1257977               Compound::DB13234
# 1984127  Biological Process::GO:0007169
# 2459037                     Gene::23051

# %%
# Create a triples factory from the DataFrame
testing_rules_factory = TriplesFactory.from_labeled_triples(df_rules_sample.values, 
    entity_to_id=rules_training_triples.entity_to_id, relation_to_id=rules_training_triples.relation_to_id)
testing_no_rules_factory = TriplesFactory.from_labeled_triples(df_no_rules_sample.values, 
    entity_to_id=no_rules_training_triples.entity_to_id, relation_to_id=no_rules_training_triples.relation_to_id)

# %%
#Load in pretrained models

import torch

model_with_rules = torch.load('TransE + rules/trained_model.pkl')
model_without_rules = torch.load('TransE (no rules)/trained_model.pkl')

# %% [markdown]
# Recommended to do Precision Recall curves according to this paper: https://arxiv.org/abs/1505.04094
# Rank based evaluation seems to be overall worse.
#
# Pykeen rank based evaluator paper here: https://github.com/pykeen/ranking-metrics-manuscript
# with associated paper: https://arxiv.org/abs/2203.07544

# %%
# Pick an evaluator

from pykeen.evaluation import RankBasedEvaluator
from pykeen.evaluation import ClassificationEvaluator
rank_evaluator = RankBasedEvaluator()
prauc_evaluator = ClassificationEvaluator()

# %%
# Evaluate base model without rules
results_without_rules =  rank_evaluator.evaluate(
    model=model_without_rules,
    mapped_triples=testing_no_rules_factory.mapped_triples,
    additional_filter_triples=[
        no_rules_training_triples.mapped_triples
    ],
)
# Out:
# Evaluating on cpu:   0%|          | 0.00/10.0k [00:00<?, ?triple/s]

# %%
results_without_rules.to_dict()
# Out:
# {'head': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.15849821275947829,
#    'adjusted_inverse_harmonic_mean_rank': 0.004017321663151037,
#    'harmonic_mean_rank': 203.08676565276016,
#    'variance': 10638845.85220839,
#    'inverse_arithmetic_mean_rank': 0.00021922069629272156,
#    'adjusted_arithmetic_mean_rank': 0.8415310271521191,
#    'standard_deviation': 3261.724367908544,
#    'z_arithmetic_mean_rank': 27.450162850319174,
#    'inverse_median_rank': 0.0002346591575736243,
#    'arithmetic_mean_rank': 4561.6131,
#    'median_rank': 4261.5,
#    'z_geometric_mean_rank': 34.302017914958,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00038098525955144015,
#    'adjusted_geometric_mean_rank_index': 0.34227114981202744,
#    'z_inverse_harmonic_mean_rank': 32.6728742428985,
#    'inverse_harmonic_mean_rank': 0.004924003771421572,
#    'median_absolute_deviation': 4186.86866505982,
#    'geometric_mean_rank': 2624.773465454721,
#    'hits_at_1': 0.0008,
#    'hits_at_3': 0.0045,
#    'hits_at_5': 0.0072,
#    'hits_at_10': 0.0096,
#    'z_hits_at_k': 28.583449346217886,
#    'adjusted_hits_at_k': 0.008685522094389402},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.15849790903039562,
#    'adjusted_inverse_harmonic_mean_rank': 0.004017321391973982,
#    'harmonic_mean_rank': 203.0867768270691,
#    'variance': 10638847.0,
#    'inverse_arithmetic_mean_rank': 0.00021922061569057405,
#    'adjusted_arithmetic_mean_rank': 0.8415313308251694,
#    'standard_deviation': 3261.724609375,
#    'z_arithmetic_mean_rank': 27.450110247752633,
#    'inverse_median_rank': 0.00023465916456189007,
#    'arithmetic_mean_rank': 4561.61474609375,
#    'median_rank': 4261.5,
#    'z_geometric_mean_rank': 34.302024750784724,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00038098529330454767,
#    'adjusted_geometric_mean_rank_index': 0.34227121802102556,
#    'z_inverse_harmonic_mean_rank': 32.67287203741571,
#    'inverse_harmonic_mean_rank': 0.004924003500491381,
#    'median_absolute_deviation': 4186.86866505982,
#    'geometric_mean_rank': 2624.773193359375,
#    'hits_at_1': 0.0008,
#    'hits_at_3': 0.0045,
#    'hits_at_5': 0.0072,
#    'hits_at_10': 0.0096,
#    'z_hits_at_k': 28.583449346217886,
#    'adjusted_hits_at_k': 0.008685522094389402},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.15849765921430636,
#    'adjusted_inverse_harmonic_mean_rank': 0.004017321310663791,
#    'harmonic_mean_rank': 203.0867801775932,
#    'variance': 10638847.63992079,
#    'inverse_arithmetic_mean_rank': 0.0002192205521196753,
#    'adjusted_arithmetic_mean_rank': 0.8415315805951724,
#    'standard_deviation': 3261.724641952596,
#    'z_arithmetic_mean_rank': 27.450066982328934,
#    'inverse_median_rank': 0.0002346591575736243,
#    'arithmetic_mean_rank': 4561.6161,
#    'median_rank': 4261.5,
#    'z_geometric_mean_rank': 34.30196145292112,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00038098493333744917,
#    'adjusted_geometric_mean_rank_index': 0.3422705864245811,
#    'z_inverse_harmonic_mean_rank': 32.67287137611998,
#    'inverse_harmonic_mean_rank': 0.004924003419255209,
#    'median_absolute_deviation': 4186.86866505982,
#    'geometric_mean_rank': 2624.7757128869757,
#    'hits_at_1': 0.0008,
#    'hits_at_3': 0.0045,
#    'hits_at_5': 0.0072,
#    'hits_at_10': 0.0096,
#    'z_hits_at_k': 28.583449346217886,
#    'adjusted_hits_at_k': 0.008685522094389402}},
#  'tail': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.08821912609180571,
#    'adjusted_inverse_harmonic_mean_rank': 0.0019292858162565348,
#    'harmonic_mean_rank': 352.35220143192015,
#    'variance': 10061148.119588392,
#    'inverse_arithmetic_mean_rank': 0.00020237642950867717,
#    'adjusted_arithmetic_mean_rank': 0.9117971526529035,
#    'standard_deviation': 3171.931291750878,
#    'z_arithmetic_mean_rank': 15.278586492775304,
#    'inverse_median_rank': 0.00021103724807428512,
#    'arithmetic_mean_rank': 4941.2869,
#    'median_rank': 4738.5,
#    'z_geometric_mean_rank': 16.91690106132029,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.0003015715532228184,
#    'adjusted_geometric_mean_rank_index': 0.16879953939418335,
#    'z_inverse_harmonic_mean_rank': 15.688957720722339,
#    'inverse_harmonic_mean_rank': 0.002838069397427095,
#    'median_absolute_deviation': 4094.9473275124724,
#    'geometric_mean_rank': 3315.9626274867596,
#    'hits_at_1': 0.0005,
#    'hits_at_3': 0.0029,
#    'hits_at_5': 0.0037,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508871482918,
#    'adjusted_hits_at_k': 0.004281233425608369},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.08821881709747681,
#    'adjusted_inverse_harmonic_mean_rank': 0.001929285758991431,
#    'harmonic_mean_rank': 352.3522085350281,
#    'variance': 10061150.0,
#    'inverse_arithmetic_mean_rank': 0.00020237636636011302,
#    'adjusted_arithmetic_mean_rank': 0.9117974615902148,
#    'standard_deviation': 3171.931640625,
#    'z_arithmetic_mean_rank': 15.278532978341559,
#    'inverse_median_rank': 0.00021103724429849535,
#    'arithmetic_mean_rank': 4941.28857421875,
#    'median_rank': 4738.5,
#    'z_geometric_mean_rank': 16.91688217883538,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00030157147557474673,
#    'adjusted_geometric_mean_rank_index': 0.1687993509817345,
#    'z_inverse_harmonic_mean_rank': 15.68895725504235,
#    'inverse_harmonic_mean_rank': 0.0028380693402141333,
#    'median_absolute_deviation': 4094.9473275124724,
#    'geometric_mean_rank': 3315.96337890625,
#    'hits_at_1': 0.0005,
#    'hits_at_3': 0.0029,
#    'hits_at_5': 0.0037,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508871482918,
#    'adjusted_hits_at_k': 0.004281233425608369},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.08821840630660294,
#    'adjusted_inverse_harmonic_mean_rank': 0.0019292852622092762,
#    'harmonic_mean_rank': 352.35227015541716,
#    'variance': 10061152.52663536,
#    'inverse_arithmetic_mean_rank': 0.0002023762697795483,
#    'adjusted_arithmetic_mean_rank': 0.9117978723052871,
#    'standard_deviation': 3171.931986445384,
#    'z_arithmetic_mean_rank': 15.27846183386103,
#    'inverse_median_rank': 0.00021103724807428512,
#    'arithmetic_mean_rank': 4941.2908,
#    'median_rank': 4738.5,
#    'z_geometric_mean_rank': 16.91681343583457,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00030157123609522154,
#    'adjusted_geometric_mean_rank_index': 0.16879866505309826,
#    'z_inverse_harmonic_mean_rank': 15.688953215208464,
#    'inverse_harmonic_mean_rank': 0.0028380688438843188,
#    'median_absolute_deviation': 4094.9473275124724,
#    'geometric_mean_rank': 3315.9661145012137,
#    'hits_at_1': 0.0005,
#    'hits_at_3': 0.0029,
#    'hits_at_5': 0.0037,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508871482918,
#    'adjusted_hits_at_k': 0.004281233425608369}},
#  'both': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.12336297777382055,
#    'adjusted_inverse_harmonic_mean_rank': 0.0029733038447440014,
#    'harmonic_mean_rank': 257.66312124273054,
#    'variance': 10386035.0345,
#    'inverse_arithmetic_mean_rank': 0.00021046206947352913,
#    'adjusted_arithmetic_mean_rank': 0.8766597831436559,
#    'standard_deviation': 3222.7371960028013,
#    'z_arithmetic_mean_rank': 30.214842125482306,
#    'inverse_median_rank': 0.00022187708009762592,
#    'arithmetic_mean_rank': 4751.45,
#    'median_rank': 4507.0,
#    'z_geometric_mean_rank': 36.93167912412012,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00033896064148795625,
#    'adjusted_geometric_mean_rank_index': 0.2605851838184028,
#    'z_inverse_harmonic_mean_rank': 34.196244728795314,
#    'inverse_harmonic_mean_rank': 0.003881036584424334,
#    'median_absolute_deviation': 4154.251416252697,
#    'geometric_mean_rank': 2950.195030344051,
#    'hits_at_1': 0.00065,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.00545,
#    'hits_at_10': 0.0074,
#    'z_hits_at_k': 30.17229470611961,
#    'adjusted_hits_at_k': 0.006483378009871382},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.12336258130614852,
#    'adjusted_inverse_harmonic_mean_rank': 0.0029733035640015035,
#    'harmonic_mean_rank': 257.66313986433676,
#    'variance': 10386036.0,
#    'inverse_arithmetic_mean_rank': 0.00021046197798568755,
#    'adjusted_arithmetic_mean_rank': 0.8766601795381781,
#    'standard_deviation': 3222.7373046875,
#    'z_arithmetic_mean_rank': 30.214745020108126,
#    'inverse_median_rank': 0.00022187708236742765,
#    'arithmetic_mean_rank': 4751.4521484375,
#    'median_rank': 4507.0,
#    'z_geometric_mean_rank': 36.93159102240455,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00033896035165525973,
#    'adjusted_geometric_mean_rank_index': 0.2605845621840148,
#    'z_inverse_harmonic_mean_rank': 34.19624149994968,
#    'inverse_harmonic_mean_rank': 0.0038810363039374356,
#    'median_absolute_deviation': 4154.251416252697,
#    'geometric_mean_rank': 2950.197509765625,
#    'hits_at_1': 0.00065,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.00545,
#    'hits_at_10': 0.0074,
#    'z_hits_at_k': 30.17229470611961,
#    'adjusted_hits_at_k': 0.006483378009871382},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.12336234111882438,
#    'adjusted_inverse_harmonic_mean_rank': 0.00297330339147676,
#    'harmonic_mean_rank': 257.6631513078775,
#    'variance': 10386038.3027331,
#    'inverse_arithmetic_mean_rank': 0.00021046191665836483,
#    'adjusted_arithmetic_mean_rank': 0.8766604196811869,
#    'standard_deviation': 3222.737703061343,
#    'z_arithmetic_mean_rank': 30.214686191906907,
#    'inverse_median_rank': 0.00022187708009762592,
#    'arithmetic_mean_rank': 4751.45345,
#    'median_rank': 4507.0,
#    'z_geometric_mean_rank': 36.93157912578205,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00033896031814982476,
#    'adjusted_geometric_mean_rank_index': 0.2605844782429747,
#    'z_inverse_harmonic_mean_rank': 34.19623951572651,
#    'inverse_harmonic_mean_rank': 0.003881036131569765,
#    'median_absolute_deviation': 4154.251416252697,
#    'geometric_mean_rank': 2950.197844568895,
#    'hits_at_1': 0.00065,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.00545,
#    'hits_at_10': 0.0074,
#    'z_hits_at_k': 30.17229470611961,
#    'adjusted_hits_at_k': 0.006483378009871382}}}

# %%
results_with_rules = rank_evaluator.evaluate(
    model=model_with_rules,
    mapped_triples=testing_rules_factory.mapped_triples,
    additional_filter_triples=[
        rules_training_triples.mapped_triples
    ],
)
# Out:
# Evaluating on cpu:   0%|          | 0.00/10.0k [00:00<?, ?triple/s]

# %%
results_with_rules.to_dict()
# Out:
# {'head': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.16059114200344415,
#    'adjusted_inverse_harmonic_mean_rank': 0.004338985543246143,
#    'harmonic_mean_rank': 190.64414294104554,
#    'variance': 10766531.17705399,
#    'inverse_arithmetic_mean_rank': 0.00021976718348069857,
#    'adjusted_arithmetic_mean_rank': 0.8394384840160561,
#    'standard_deviation': 3281.239274581174,
#    'z_arithmetic_mean_rank': 27.81263538262155,
#    'inverse_median_rank': 0.00023866348448687351,
#    'arithmetic_mean_rank': 4550.2699,
#    'median_rank': 4190.0,
#    'z_geometric_mean_rank': 34.96052539244559,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.0003848282479039973,
#    'adjusted_geometric_mean_rank_index': 0.34884184517327277,
#    'z_inverse_harmonic_mean_rank': 35.28896505347471,
#    'inverse_harmonic_mean_rank': 0.005245374888381639,
#    'median_absolute_deviation': 4247.655356018549,
#    'geometric_mean_rank': 2598.5618401107317,
#    'hits_at_1': 0.0012,
#    'hits_at_3': 0.0046,
#    'hits_at_5': 0.0061,
#    'hits_at_10': 0.0108,
#    'z_hits_at_k': 32.53621087683163,
#    'adjusted_hits_at_k': 0.009886630037304842},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.16059057937663046,
#    'adjusted_inverse_harmonic_mean_rank': 0.004338985636263125,
#    'harmonic_mean_rank': 190.6441395634034,
#    'variance': 10766536.0,
#    'inverse_arithmetic_mean_rank': 0.00021976704010739923,
#    'adjusted_arithmetic_mean_rank': 0.8394390465390759,
#    'standard_deviation': 3281.239990234375,
#    'z_arithmetic_mean_rank': 27.81253794178994,
#    'inverse_median_rank': 0.00023866348783485591,
#    'arithmetic_mean_rank': 4550.27294921875,
#    'median_rank': 4190.0,
#    'z_geometric_mean_rank': 34.96047201296658,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00038482793024741113,
#    'adjusted_geometric_mean_rank_index': 0.34884131254409323,
#    'z_inverse_harmonic_mean_rank': 35.28896580998173,
#    'inverse_harmonic_mean_rank': 0.005245374981313944,
#    'median_absolute_deviation': 4247.655356018549,
#    'geometric_mean_rank': 2598.56396484375,
#    'hits_at_1': 0.0012,
#    'hits_at_3': 0.0046,
#    'hits_at_5': 0.0061,
#    'hits_at_10': 0.0108,
#    'z_hits_at_k': 32.53621087683163,
#    'adjusted_hits_at_k': 0.009886630037304842},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.16059009026754034,
#    'adjusted_inverse_harmonic_mean_rank': 0.0043389848088551996,
#    'harmonic_mean_rank': 190.6441696083287,
#    'variance': 10766540.866444642,
#    'inverse_arithmetic_mean_rank': 0.00021976690818463832,
#    'adjusted_arithmetic_mean_rank': 0.8394395355579347,
#    'standard_deviation': 3281.240751064244,
#    'z_arithmetic_mean_rank': 27.812453233426737,
#    'inverse_median_rank': 0.00023866348448687351,
#    'arithmetic_mean_rank': 4550.2756,
#    'median_rank': 4190.0,
#    'z_geometric_mean_rank': 34.96042515912907,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.0003848276570565592,
#    'adjusted_geometric_mean_rank_index': 0.34884084502883295,
#    'z_inverse_harmonic_mean_rank': 35.28895908067391,
#    'inverse_harmonic_mean_rank': 0.005245374154659241,
#    'median_absolute_deviation': 4247.655356018549,
#    'geometric_mean_rank': 2598.5658298281487,
#    'hits_at_1': 0.0012,
#    'hits_at_3': 0.0046,
#    'hits_at_5': 0.0061,
#    'hits_at_10': 0.0108,
#    'z_hits_at_k': 32.53621087683163,
#    'adjusted_hits_at_k': 0.009886630037304842}},
#  'tail': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.0864825443779883,
#    'adjusted_inverse_harmonic_mean_rank': 0.0019768837952117346,
#    'harmonic_mean_rank': 346.545489685809,
#    'variance': 9993961.021144789,
#    'inverse_arithmetic_mean_rank': 0.00020199179666875532,
#    'adjusted_arithmetic_mean_rank': 0.9135334139221,
#    'standard_deviation': 3161.3226695712015,
#    'z_arithmetic_mean_rank': 14.977829558452669,
#    'inverse_median_rank': 0.0002099517111064455,
#    'arithmetic_mean_rank': 4950.6961,
#    'median_rank': 4763.0,
#    'z_geometric_mean_rank': 16.69009222563129,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.0003007529365635418,
#    'adjusted_geometric_mean_rank_index': 0.16653640461896624,
#    'z_inverse_harmonic_mean_rank': 16.076024472522164,
#    'inverse_harmonic_mean_rank': 0.002885624051568633,
#    'median_absolute_deviation': 4040.0910454277655,
#    'geometric_mean_rank': 3324.988315745753,
#    'hits_at_1': 0.0007,
#    'hits_at_3': 0.0028,
#    'hits_at_5': 0.0033,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508685632674,
#    'adjusted_hits_at_k': 0.004281233408646684},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.08648214901519535,
#    'adjusted_inverse_harmonic_mean_rank': 0.0019768833454301316,
#    'harmonic_mean_rank': 346.5455436526049,
#    'variance': 9993963.0,
#    'inverse_arithmetic_mean_rank': 0.0002019917155848816,
#    'adjusted_arithmetic_mean_rank': 0.9135338092119382,
#    'standard_deviation': 3161.322998046875,
#    'z_arithmetic_mean_rank': 14.97776108594681,
#    'inverse_median_rank': 0.00020995171507820487,
#    'arithmetic_mean_rank': 4950.6982421875,
#    'median_rank': 4763.0,
#    'z_geometric_mean_rank': 16.690093092478037,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.0003007529303431511,
#    'adjusted_geometric_mean_rank_index': 0.16653641326850155,
#    'z_inverse_harmonic_mean_rank': 16.07602081489693,
#    'inverse_harmonic_mean_rank': 0.002885623602196574,
#    'median_absolute_deviation': 4040.0910454277655,
#    'geometric_mean_rank': 3324.98828125,
#    'hits_at_1': 0.0007,
#    'hits_at_3': 0.0028,
#    'hits_at_5': 0.0033,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508685632674,
#    'adjusted_hits_at_k': 0.004281233408646684},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.08648176922467865,
#    'adjusted_inverse_harmonic_mean_rank': 0.001976882467183017,
#    'harmonic_mean_rank': 346.54564902864587,
#    'variance': 9993964.407279909,
#    'inverse_arithmetic_mean_rank': 0.00020199162530601982,
#    'adjusted_arithmetic_mean_rank': 0.9135341889323736,
#    'standard_deviation': 3161.3232051278637,
#    'z_arithmetic_mean_rank': 14.97769531038864,
#    'inverse_median_rank': 0.0002099517111064455,
#    'arithmetic_mean_rank': 4950.7003,
#    'median_rank': 4763.0,
#    'z_geometric_mean_rank': 16.689984869736193,
#    'count': 10000.0,
#    'inverse_geometric_mean_rank': 0.00030075255013571416,
#    'adjusted_geometric_mean_rank_index': 0.16653533340470683,
#    'z_inverse_harmonic_mean_rank': 16.07601367298897,
#    'inverse_harmonic_mean_rank': 0.002885622724749139,
#    'median_absolute_deviation': 4040.0910454277655,
#    'geometric_mean_rank': 3324.9925879223683,
#    'hits_at_1': 0.0007,
#    'hits_at_3': 0.0028,
#    'hits_at_5': 0.0033,
#    'hits_at_10': 0.0052,
#    'z_hits_at_k': 14.087508685632674,
#    'adjusted_hits_at_k': 0.004281233408646684}},
#  'both': {'optimistic': {'adjusted_arithmetic_mean_rank_index': 0.1235413852755255,
#    'adjusted_inverse_harmonic_mean_rank': 0.003157934788029479,
#    'harmonic_mean_rank': 245.97223720856024,
#    'variance': 10420331.384511,
#    'inverse_arithmetic_mean_rank': 0.00021050491076381075,
#    'adjusted_arithmetic_mean_rank': 0.8764814085598343,
#    'standard_deviation': 3228.053807561299,
#    'z_arithmetic_mean_rank': 30.25853882118878,
#    'inverse_median_rank': 0.00022177866489243733,
#    'arithmetic_mean_rank': 4750.483,
#    'median_rank': 4509.0,
#    'z_geometric_mean_rank': 37.31455850349147,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00034020321225662994,
#    'adjusted_geometric_mean_rank_index': 0.2632867315396549,
#    'z_inverse_harmonic_mean_rank': 36.31970158605247,
#    'inverse_harmonic_mean_rank': 0.004065499469975135,
#    'median_absolute_deviation': 4173.525245093269,
#    'geometric_mean_rank': 2939.4196291293597,
#    'hits_at_1': 0.00095,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.0047,
#    'hits_at_10': 0.008,
#    'z_hits_at_k': 32.9671476748672,
#    'adjusted_hits_at_k': 0.007083932040920181},
#   'realistic': {'adjusted_arithmetic_mean_rank_index': 0.123540861217324,
#    'adjusted_inverse_harmonic_mean_rank': 0.003157934493125789,
#    'harmonic_mean_rank': 245.97225503468093,
#    'variance': 10420335.0,
#    'inverse_arithmetic_mean_rank': 0.0002105047897202894,
#    'adjusted_arithmetic_mean_rank': 0.8764819325213451,
#    'standard_deviation': 3228.054443359375,
#    'z_arithmetic_mean_rank': 30.25841046553373,
#    'inverse_median_rank': 0.0002217786677647382,
#    'arithmetic_mean_rank': 4750.48583984375,
#    'median_rank': 4509.0,
#    'z_geometric_mean_rank': 37.31448737566939,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00034020296880044043,
#    'adjusted_geometric_mean_rank_index': 0.263286229670879,
#    'z_inverse_harmonic_mean_rank': 36.319698194337704,
#    'inverse_harmonic_mean_rank': 0.004065499175339937,
#    'median_absolute_deviation': 4173.525245093269,
#    'geometric_mean_rank': 2939.421630859375,
#    'hits_at_1': 0.00095,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.0047,
#    'hits_at_10': 0.008,
#    'z_hits_at_k': 32.9671476748672,
#    'adjusted_hits_at_k': 0.007083932040920181},
#   'pessimistic': {'adjusted_arithmetic_mean_rank_index': 0.1235404718139671,
#    'adjusted_inverse_harmonic_mean_rank': 0.00315793375681968,
#    'harmonic_mean_rank': 245.97229954238057,
#    'variance': 10420337.621954797,
#    'inverse_arithmetic_mean_rank': 0.00021050469141806793,
#    'adjusted_arithmetic_mean_rank': 0.8764823218528557,
#    'standard_deviation': 3228.054773691859,
#    'z_arithmetic_mean_rank': 30.258315090396366,
#    'inverse_median_rank': 0.00022177866489243733,
#    'arithmetic_mean_rank': 4750.48795,
#    'median_rank': 4509.0,
#    'z_geometric_mean_rank': 37.314411221565024,
#    'count': 20000.0,
#    'inverse_geometric_mean_rank': 0.00034020273253240036,
#    'adjusted_geometric_mean_rank_index': 0.26328569233730115,
#    'z_inverse_harmonic_mean_rank': 36.31968972601269,
#    'inverse_harmonic_mean_rank': 0.0040654984397041904,
#    'median_absolute_deviation': 4173.525245093269,
#    'geometric_mean_rank': 2939.4237740426192,
#    'hits_at_1': 0.00095,
#    'hits_at_3': 0.0037,
#    'hits_at_5': 0.0047,
#    'hits_at_10': 0.008,
#    'z_hits_at_k': 32.9671476748672,
#    'adjusted_hits_at_k': 0.007083932040920181}}}
